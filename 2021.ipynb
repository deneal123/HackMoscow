# %%
#Импортируем библиотеки
import numpy as np
import pandas as pd
import copy
import re
import openpyxl

# %%
# Читаем таблицу 2021.
df = pd.read_excel("C:/Users/NightMare/Desktop/YandexHack/2021.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3124 entries, 0 to 3123
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  3124 non-null   object
#  1   Год сметы                   3124 non-null   int64
#  2   Смета                       3124 non-null   object
#  3   Подразделение БР            3124 non-null   object
#  4   Код статьи                  3124 non-null   float64
#  5   Код вида расходов           3124 non-null   object
#  6   Наименование вида расходов  3124 non-null   object
#  7   Направление расходов        3124 non-null   object
#  8   Отнесено                    3124 non-null   float64
#  9   Конечный остаток            3124 non-null   float64
#  10  Дата проведения             3124 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 268.6+ KB

# %%
df.head()
# Out:
#                                           Unnamed: 0  Год сметы  \
# 0  Итого по направлению - ЗО ЗО. ДГУ. Оплата за э...       2021
# 1  Итого по направлению - 134.1000.01 ДГУ. Оплата...       2021
# 2  Итого по направлению - 134.1000.01 ДГУ. Оплата...       2021
# 3  Итого по направлению - 134.1000.01 ДГУ. Оплата...       2021
# 4  Итого по направлению - 134.1000.01 ДГУ. Оплата...       2021
#
#                                                Смета  \
# 0  Аппарат Дальневосточного ГУ Банка России г. Вл...
# 1  Аппарат Дальневосточного ГУ Банка России г. Вл...
# 2  Аппарат Дальневосточного ГУ Банка России г. Вл...
# 3  Аппарат Дальневосточного ГУ Банка России г. Вл...
# 4  Аппарат Дальневосточного ГУ Банка России г. Вл...
#
#                                     Подразделение БР  Код статьи  \
# 0  Дальневосточное главное управление Центральног...       134.1
# 1  Дальневосточное главное управление Центральног...       134.1
# ...

# %%
# Выкидываем дату проведения.
df = df.drop(['Смета', 'Год сметы', 'Подразделение БР', 'Код вида расходов', 'Unnamed: 0', 'Код статьи', 'Отнесено'], axis=1)

df.head()
# Out:
#           Наименование вида расходов  \
# 0  Оплата потребления электроэнергии
# 1  Оплата потребления электроэнергии
# 2  Оплата потребления электроэнергии
# 3  Оплата потребления электроэнергии
# 4  Оплата потребления электроэнергии
#
#                                 Направление расходов  Конечный остаток  \
# 0  ЗО ЗО. ДГУ. Оплата за электроэнергию по тарифа...          13920.02
# 1  134.1000.01 ДГУ. Оплата за электроэнергию по т...            226.79
# 2  134.1000.01 ДГУ. Оплата за электроэнергию по т...            161.12
# 3  134.1000.01 ДГУ. Оплата за электроэнергию по т...            115.67
# 4  134.1000.01 ДГУ. Оплата за электроэнергию по т...            126.38
#
#   Дата проведения
# 0      13.01.2022
# 1      19.01.2021
# 2      20.02.2021
# 3      22.03.2021
# 4      21.04.2021

# %%
# Переносим Конечный остаток вправо.
new_order = [col for col in df.columns if col != 'Конечный остаток'] + ['Конечный остаток']
df = df[new_order]

# %%
df.head()
# Out:
#           Наименование вида расходов  \
# 0  Оплата потребления электроэнергии
# 1  Оплата потребления электроэнергии
# 2  Оплата потребления электроэнергии
# 3  Оплата потребления электроэнергии
# 4  Оплата потребления электроэнергии
#
#                                 Направление расходов Дата проведения  \
# 0  ЗО ЗО. ДГУ. Оплата за электроэнергию по тарифа...      13.01.2022
# 1  134.1000.01 ДГУ. Оплата за электроэнергию по т...      19.01.2021
# 2  134.1000.01 ДГУ. Оплата за электроэнергию по т...      20.02.2021
# 3  134.1000.01 ДГУ. Оплата за электроэнергию по т...      22.03.2021
# 4  134.1000.01 ДГУ. Оплата за электроэнергию по т...      21.04.2021
#
#    Конечный остаток
# 0          13920.02
# 1            226.79
# 2            161.12
# 3            115.67
# 4            126.38

# %%
# Задайте максимальную ширину столбца
pd.set_option('display.max_colwidth', None)

# Выведите данные
print(df['Направление расходов'].head(10))
type_JKY = df['Направление расходов']
# Out:
# 0          ЗО ЗО. ДГУ. Оплата за электроэнергию по тарифам  ул.Мордовцева, 6
# 1    134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Пушкинская, 8б
# 2    134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Пушкинская, 8б
# 3    134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Пушкинская, 8б
# 4    134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Пушкинская, 8б
# 5    134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Пушкинская, 8б
# 6    134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Пушкинская, 8б
# 7    134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Пушкинская, 8б
# 8    134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Пушкинская, 8б
# 9    134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Пушкинская, 8б
# Name: Направление расходов, dtype: object

# %%
pd.set_option('display.max_colwidth', None)

def process_substring(value, substring):
    if substring in value:
        new_value = value.split(substring, 1)[1].strip()
        return new_value
    return value

substrings_to_process = [
    'зд. ',
    'зд.',
    'здание',
    'по тарифам  ',
    'по тарифам ',
    'по тарифам,',
    'ул.',
    'ул. ',
    'г.',
    'с.',
    'сточных вод',
    'централ.систему водоотведения',
    'за услуги водоотведения',
    'за холодное водоснабжение',
    'топлива (отопление)',
    'холодного водоснабжения',
    'услуг водоотведения'
    
]

for substring in substrings_to_process:
    df['Направление расходов'] = df['Направление расходов'].apply(lambda x: process_substring(x, substring))

def remove_suffix_from_column(column, suffix):
    # Создаем новый список для хранения строк без суффикса
    new_column = []

    # Перебираем каждую строку в столбце
    for row in column:
        # Проверяем, заканчивается ли текущая строка на заданный суффикс
        if row.endswith(suffix):
            # Если да, удаляем суффикс и добавляем строку в новый список
            new_row = row[:-len(suffix)]
            new_column.append(new_row)
        else:
            # Если нет, просто добавляем строку в новый список
            new_column.append(row)

    return new_column

suffixes_to_remove = [
    "-  ст.134.1100",
    " ст.134.1100",
    "-",
    " -",
    ",",
    "- ",
    "- ст. 134.1100",
    " -  ",
    ", "
    "Здание ",
    " -ст.134.1100",
    ". Здание ",
    "-ст.134.1100",
    " ст. 134.1100",
    "-ст.1341100",
    "ст.134.1100"
]

for suffix in suffixes_to_remove:
    df['Направление расходов'] = remove_suffix_from_column(df['Направление расходов'], suffix)
    
# Выведите уникальные значения
for value in df['Направление расходов'].unique():
    print(value)
# Out:
# Мордовцева, 6
# Пушкинская, 8б
# Седова, 32
# Фонтанная, 19
# Семеновская, 29
# Калинина, 261
# Океанский пр-т, 34
# Светланская, 71
# Светланская,69
# Светланская, 111
# Светланская,71 Пристройка
# Светланская,73
# Светланская,73 А
# Ленина, 64
# РКЦ Находка
# РКЦ Уссурийск
# Пушкина, 59
# РКЦ Уссурийск (гараж)
# Светланская, 73
# Светланская, 73 А
# Светланская, 71 пристройка
# Пушкинская,8б
# Дальнегорск, пр-т 50 лет Октября, 89
# Светланская, 69
# Океанский пр-т 34
# Светланская, 73а
# Некрасова, 102 (гараж)
# Пушкина, 8б
# Светланская, 73А
# Дежнева, 7
# Дежнева, 7 дизель-генераторная установка
# Колхозная 32 Б (склад)
# Южная, 1а (гараж)
# п. Эгвекинот
# Билибино
# Дежнева 7
# пгт. Эгвекинот
# Южная 1а
# Чапаева,5а
# пр-т 60-летия СССР, 5
# Миллера, 1а, корпус 1 (гараж)
# Миллера, 1а, корпус 2 (гаражный бокс 1-2)
# Чапаева, 5А
# Зея пер. Жуковский,15, Гараж
#
# . (Пристройка)
# Благовещенск, пер. Святителя Иннокентия, 17, Пристройка к зданию (Новая)
# ...

# %%
len(df['Направление расходов'])
# Out:
# 3124

# %%
df.insert(loc=df.columns.get_loc('Направление расходов') + 1, column='Вид объекта', value=0)
df.head()
# Out:
#           Наименование вида расходов Направление расходов  Вид объекта  \
# 0  Оплата потребления электроэнергии        Мордовцева, 6            0
# 1  Оплата потребления электроэнергии       Пушкинская, 8б            0
# 2  Оплата потребления электроэнергии       Пушкинская, 8б            0
# 3  Оплата потребления электроэнергии       Пушкинская, 8б            0
# 4  Оплата потребления электроэнергии       Пушкинская, 8б            0
#
#   Дата проведения  Конечный остаток
# 0      13.01.2022          13920.02
# 1      19.01.2021            226.79
# 2      20.02.2021            161.12
# 3      22.03.2021            115.67
# 4      21.04.2021            126.38

# %%
def compare_and_assign(df, column_name, replacements):
    for index, value in df[column_name].items():
        for replacement in replacements:
            target_string = replacement['target']
            new_value = replacement['new_value']
            # Удаляем пробелы с обеих сторон строки перед проверкой
            if value.rstrip().endswith(target_string):
                df.at[index, "Вид объекта"] = new_value
                # Удаляем target строку из строки с которой сравнивали
                df.at[index, column_name] = value.replace(target_string, '').strip()
    return df[column_name]  # Возвращаем измененный столбец

# Заменяем значения, оканчивающиеся на "(Буфет)"
replacements = [
    {'target': '(Буфет)', 'new_value': 'буфет'},
    {'target': '(Столовая)', 'new_value': 'столовая'},
    {'target': '(ГАРАЖ на 10 автомобилей)', 'new_value': 'большой гараж'},
    {'target': '(гаражный бокс 1-2)', 'new_value': 'большой гараж'},
    {'target': 'Пристройка', 'new_value': 'пристройка'},
    {'target': 'пристройка', 'new_value': 'пристройка'},
    {'target': '( гараж на 10 а/м)', 'new_value': 'большой гараж'},
    {'target': ', Административное (Пристройка)', 'new_value': 'пристройка'},\
    {'target': ', Пристройка к зданию (Новая)', 'new_value': 'пристройка'},
    {'target': ', Помещение объект № 2', 'new_value': 'помещение'},
    {'target': ', Помещение объект №2', 'new_value': 'помещение'},
    {'target': ', Пристройка к зданию (новая)', 'new_value': 'пристройка к зданию'},
    {'target': ', Контрольно-пропускной пункт', 'new_value': 'КПП'},
    {'target': ', КПП', 'new_value': 'КПП'},
    {'target': ', Гараж', 'new_value': 'гараж'},
    {'target': ' (гараж)', 'new_value': 'гараж'},
    {'target': ' (жилой подъезд)', 'new_value': 'жилой подъезд'},
    {'target': ' (функц. помещение)', 'new_value': 'функц. помещение'},
    {'target': ' (жилая часть)', 'new_value': 'жилая часть'},
    {'target': ' (шахтн. канализац. станция)', 'new_value': 'шахтн. канализац. станция'},
    {'target': '-', 'new_value': ''},
    {'target': 'дизель-генераторная установка', 'new_value': 'генератор'},
    {'target': '(склад)', 'new_value': 'склад'},
    {'target': '(буфет)', 'new_value': 'буфет'},
    {'target': '(столовая)', 'new_value': 'столовая'},
    {'target': '(Гараж)', 'new_value': 'гараж'},
    {'target': ', Помещение Объект №2', 'new_value': 'помещение'}
]
df['Направление расходов'] = compare_and_assign(df, 'Направление расходов', replacements)

def compare_and_assign_prefix(df, column_name, replacements):
    for index, value in df[column_name].items():
        for replacement in replacements:
            target_string = replacement['target']
            new_value = replacement['new_value']
            # Удаляем пробелы с обеих сторон строки перед проверкой
            if value.lstrip().startswith(target_string):
                df.at[index, "Вид объекта"] = new_value
                # Удаляем target строку из строки с которой сравнивали
                df.at[index, column_name] = value.replace(target_string, '', 1).strip()
    return df[column_name]  # Возвращаем измененный столбец

replacements = [
    {'target': '(Гараж)  ', 'new_value': 'гараж'},
    {'target': 'Оплата за электроэнергию по тарифам', 'new_value': ''},
    {'target': 'Оплата за водоотведение по тарифам', 'new_value': ''},
    {'target': 'Оплата за холодное водоснабжение по тарифам', 'new_value': ''},
    {'target': 'Расходы по оплате холодного водоснабжения ', 'new_value': ''},
    {'target': 'Расходы по оплате водоотведения ', 'new_value': ''},
    {'target': 'Расходы по оплате холодного водоснабжения ', 'new_value': ''},
    {'target': 'Расходы по приобретению дизельного топлива (отопление) ', 'new_value': ''},
    {'target': 'Расходы по оплате отопления ', 'new_value': ''},
    {'target': 'Расходы по оплате потребления электроэнергии ', 'new_value': ''},
    {'target': '(Пристройка)', 'new_value': ''},
    {'target': '(склад) ', 'new_value': 'склад'},
    {'target': ', ', 'new_value': ''},
    {'target': 'Оплата за дизельное топливо ', 'new_value': ''},
    {'target': 'ст.134.1100', 'new_value': ''},
    {'target': 'Оплата за дизельное топливо  ', 'new_value': ''},
    {'target': 'ст.134.1100', 'new_value': ''},
    {'target': ' ', 'new_value': ''},
    {'target': 'Убежище ', 'new_value': 'убежище'},
    {'target': 'Склад ', 'new_value': 'склад'},
    {'target': ')   ', 'new_value': ''},
    {'target': ')', 'new_value': ''},
    {'target': '. (Пристройка)', 'new_value': ''},
    {'target': 'Плата за технологическое присоединение к электрическим сетям (в случаях, не связанным со строительством,реконстр. и кап.ремонтом ', 'new_value': ''},
    {'target': 'Другие расходы прошлых лет, выявленные в текущем году. Расходы на коммунальные услуги', 'new_value': ''},
    {'target': '134.1000.05 Хабаровск. Расходы по коммунальным услугам (расходы прошлых лет)', 'new_value': ''},
    {'target': 'БУФЕТ', 'new_value': ''},
    {'target': 'ЗО 134.1000.01 Столовая Камчатка. Оплата за электроэнергию по тарифам', 'new_value': ''},
    {'target': '134.1000.02 Столовая Камчатка. Оплата за дизельное топливо', 'new_value': ''},
    {'target': '.(Пристройка)', 'new_value': ''},
    {'target': '134.1000.01 Столовая Камчатка. Оплата за электроэнергию по тарифам', 'new_value': ''},
    {'target': '134.1000.05 Столовая Хаб.Расходы по оплате коммунальных услуг (расходы прошлых лет)', 'new_value': ''}
]
df['Направление расходов'] = compare_and_assign_prefix(df, 'Направление расходов', replacements)


def replace_zero_values(df, column_name, replacement_value):
    df[column_name] = df[column_name].replace(0, replacement_value)
    return df[column_name]

replacement_value = 'Здание'
df['Вид объекта'] = replace_zero_values(df, 'Вид объекта', replacement_value)

def drop_rows_with_empty_values(df):
    # Удаляем строки, содержащие хотя бы одно из значений: 0, NaN, пустую строку или пробелы
    df = df.dropna().replace({'': None, ' ': None}).dropna()
    return df

# Удаляем строки с пустыми значениями
df= drop_rows_with_empty_values(df)

# Вывод уникальных значений
for index, value in df['Направление расходов'].items():
    print(f' Адрес: {value} --------- Вид объекта: {df.at[index, "Вид объекта"]}')
# Out:
#  Адрес: Мордовцева, 6 --------- Вид объекта: Здание
#  Адрес: Пушкинская, 8б --------- Вид объекта: Здание
#  Адрес: Пушкинская, 8б --------- Вид объекта: Здание
#  Адрес: Пушкинская, 8б --------- Вид объекта: Здание
#  Адрес: Пушкинская, 8б --------- Вид объекта: Здание
#  Адрес: Пушкинская, 8б --------- Вид объекта: Здание
#  Адрес: Пушкинская, 8б --------- Вид объекта: Здание
#  Адрес: Пушкинская, 8б --------- Вид объекта: Здание
#  Адрес: Пушкинская, 8б --------- Вид объекта: Здание
#  Адрес: Пушкинская, 8б --------- Вид объекта: Здание
#  Адрес: Пушкинская, 8б --------- Вид объекта: Здание
#  Адрес: Седова, 32 --------- Вид объекта: Здание
#  Адрес: Седова, 32 --------- Вид объекта: Здание
#  Адрес: Седова, 32 --------- Вид объекта: Здание
#  Адрес: Седова, 32 --------- Вид объекта: Здание
#  Адрес: Седова, 32 --------- Вид объекта: Здание
#  Адрес: Седова, 32 --------- Вид объекта: Здание
#  Адрес: Седова, 32 --------- Вид объекта: Здание
# ...

# %%
# Выведите уникальные значения
for value in df['Направление расходов'].unique():
    print(value)
# Out:
# Мордовцева, 6
# Пушкинская, 8б
# Седова, 32
# Фонтанная, 19
# Семеновская, 29
# Калинина, 261
# Океанский пр-т, 34
# Светланская, 71
# Светланская,69
# Светланская, 111
# Светланская,71
# Светланская,73
# Светланская,73 А
# Ленина, 64
# РКЦ Находка
# РКЦ Уссурийск
# Пушкина, 59
# Светланская, 73
# Светланская, 73 А
# Пушкинская,8б
# Дальнегорск, пр-т 50 лет Октября, 89
# Светланская, 69
# Океанский пр-т 34
# Светланская, 73а
# Некрасова, 102
# Пушкина, 8б
# Светланская, 73А
# Дежнева, 7
# Колхозная 32 Б
# Южная, 1а
# п. Эгвекинот
# Билибино
# Дежнева 7
# пгт. Эгвекинот
# Южная 1а
# Чапаева,5а
# пр-т 60-летия СССР, 5
# Миллера, 1а, корпус 1
# Миллера, 1а, корпус 2
# Чапаева, 5А
# Зея пер. Жуковский,15
# Благовещенск, пер. Святителя Иннокентия, 17
# Б. Хмельницкого, 52/2
# Красная Пресня, 22
# Зея, пер. Жуковский,15
# п-кт .К.Маркса,36-20, кв.29
# Пушкина, 4
# Пушкина,6
# Магадан, п-кт. Карла Маркса, д. 36/20, кв. 29
# Пушкина, д.4
# Пушкина, д. 4
# пр-тК.Маркса, 29/2
# Ленинская, 22
# ...

# %%
print(len(df['Направление расходов']))
# Out:
# 2867

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2867 entries, 0 to 3122
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Наименование вида расходов  2867 non-null   object
#  1   Направление расходов        2867 non-null   object
#  2   Вид объекта                 2867 non-null   object
#  3   Дата проведения             2867 non-null   object
#  4   Конечный остаток            2867 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 198.9+ KB

# %%
df.head()
# Out:
#           Наименование вида расходов Направление расходов Вид объекта  \
# 0  Оплата потребления электроэнергии        Мордовцева, 6      Здание
# 1  Оплата потребления электроэнергии       Пушкинская, 8б      Здание
# 2  Оплата потребления электроэнергии       Пушкинская, 8б      Здание
# 3  Оплата потребления электроэнергии       Пушкинская, 8б      Здание
# 4  Оплата потребления электроэнергии       Пушкинская, 8б      Здание
#
#   Дата проведения  Конечный остаток
# 0      13.01.2022          13920.02
# 1      19.01.2021            226.79
# 2      20.02.2021            161.12
# 3      22.03.2021            115.67
# 4      21.04.2021            126.38

# %%
type_JKY.head()
# Out:
# 0          ЗО ЗО. ДГУ. Оплата за электроэнергию по тарифам  ул.Мордовцева, 6
# 1    134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Пушкинская, 8б
# 2    134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Пушкинская, 8б
# 3    134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Пушкинская, 8б
# 4    134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Пушкинская, 8б
# Name: Направление расходов, dtype: object

# %%
# Выведите уникальные значения
for value in type_JKY.unique():
    print(value)
# Out:
# ЗО ЗО. ДГУ. Оплата за электроэнергию по тарифам  ул.Мордовцева, 6
# 134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Пушкинская, 8б
# 134.1000.01 ДГУ. Оплата за электроэнергию по тарифам с.Вл-Александровское, ул.Седова, 32
# 134.1000.01 ДГУ. Оплата за электроэнергию по тарифам ул.Фонтанная, 19
# 134.1000.01 ДГУ. Оплата за электроэнергию по тарифам ул.Семеновская, 29
# 134.1000.01 ДГУ. Оплата за электроэнергию по тарифам ул.Калинина, 261
# 134.1000.01 ДГУ. Оплата за электроэнергию по тарифам Океанский пр-т, 34
# 134.1000.01 ДГУ. Оплата за электроэнергию по тарифам ул.Светланская, 71
# 134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Мордовцева, 6
# 134.1000.01 ДГУ. Оплата за электроэнергию по тарифам ул.Светланская,69
# 134.1000.01 ДГУ. Оплата за электроэнергию по тарифам  ул.Светланская, 111
# 134.1000.01 ДГУ. Оплата за электроэнергию по тарифам ул.Светланская,71 Пристройка
# 134.1000.01 ДГУ. Оплата за электроэнергию по тарифам ул.Светланская,73
# ...

# %%
def replace_words_in_column(column, replacement_dict):
    new_column = column.copy()
    for search_word, replace_word in replacement_dict.items():
        new_column = new_column.apply(lambda x: replace_word if search_word in x else x)
    return new_column


replacement_dict = {'Оплата за водоотведение по тарифам': 'ВО',
                    'Оплата водоотведения по тарифам': 'ВО',
                    'Оплата за  водоотведение по тарифам': 'ВО',
                    'Оплата за горячее водоснабжение по тарифам': 'ГВС',
                    'Оплата за тепловую энергию по тарифам': 'ТЭ',
                    'Оплата за холодное водоснабжение по тарифам': 'ХВС',
                    'Оплата за электроэнергию по тарифам': 'ЭЭ',
                    'Оплата за холодное водоснабжение  по тарифам': 'ХВС',
                    'Оплата за дизельное топливо': 'ДТ',
                    'Оплата потребления газа по тарифам': 'ПГ',
                    'Плата за технологическое присоединение к электрическим сетям': 'ТПЭС',
                    'Другие расходы': 'ДР',
                    'Оплата за горячее  водоснабжение по тарифам': 'ГВС',
                    'Оплата за эектроэнергию по тарифам': 'ЭЭ',
                    'Оплата за  горячее водоснабжение по тарифам': 'ГВС',
                    'Оплата за  тепловую энергию по тарифам': 'ТЭ',
                    'Оплата за  электроэнергию по тарифам': 'ЭЭ',
                    'Оплата за горячее водоснабжение  по тарифам здание (гараж': 'ГВС',
                    'Оплата за электроэнергию  по тарифам': 'ЭЭ',
                    'Оплата за тепловую энергию  по тарифам': 'ЭЭ',
                    'Оплата за водоотведение  по тарифам': 'ВО',
                    'Расходы по оплате потребления электроэнергии': 'ПЭ',
                    'Расходы по оплате отопления': 'О',
                    'Оплата за водоотведение  по тарифам': 'ВО',
                    'Расходы по приобретению дизельного топлива': 'ДТ',
                    'Расходы по оплате водоотведения': 'ВО',
                    'Оплата за водоотведение  по тарифам': 'ВО',
                    'Расходы по оплате холодного водоснабжения': 'ХВС',
                    'Расходы по оплате услуг за холодное водоснабжение по тарифам': 'ХВС',
                    'расходы по оплате услуг за холодное водоснабжение по тарифа': 'ХВС',
                    'Технологическое присоединение': 'ТП',
                    'сброс сточных вод': 'ССВ',
                    'негативное воздействие на централ.систему водоотведения': 'НВВО',
                    'за услуги водоотведения': 'ВО',
                    'за холодное водоснабжение': 'ХВС',
                    'Расходы по оплате по тарифам за электроэнергию': 'ЭЭ',
                    'услуг за горячее водоснабжение': 'ГВС',
                    'Оплата услуг водоотведения': 'ВО',
                    'Оплата за  электроэнергию  по тарифам': 'ЭЭ',
                    '(ХВС)': 'ХВС',
                    '(ГВС)': 'ГВС',
                    'за услуги горячего водоснабжения': 'ГВС',
                    'за услуги холодного водоснабжения': 'ХВС',
                    'Оплата потребления электроэнергии по тарифам': 'ЭЭ',
                    'расходы прошлых лет': 'РПЛ',
                    'Оплата холодного водоснабжения': 'ХВС',
                    'Плата за негативное воздействие на центральные системы водоотведения': 'НВВО',
                    'Оплата за потребление газа': 'ПГ'
                   }
type_JKY = replace_words_in_column(type_JKY, replacement_dict)

# %%
# Выведите уникальные значения
for value in type_JKY.unique():
    print(value)
# Out:
# ЭЭ
# ТП
# ТЭ
# ССВ
# НВВО
# ВО
# ХВС
# ГВС
# ДТ
# РПЛ
# ПГ
# 134.1000.04 Якутия Оплата потребления газа г. Вилюйск

# %%
def replace_column(dataframe, column_name, new_values):
    dataframe[column_name] = new_values
    return dataframe

df = replace_column(df, 'Наименование вида расходов', type_JKY)

df.head()
# Out:
#   Наименование вида расходов Направление расходов Вид объекта Дата проведения  \
# 0                         ЭЭ        Мордовцева, 6      Здание      13.01.2022
# 1                         ЭЭ       Пушкинская, 8б      Здание      19.01.2021
# 2                         ЭЭ       Пушкинская, 8б      Здание      20.02.2021
# 3                         ЭЭ       Пушкинская, 8б      Здание      22.03.2021
# 4                         ЭЭ       Пушкинская, 8б      Здание      21.04.2021
#
#    Конечный остаток
# 0          13920.02
# 1            226.79
# 2            161.12
# 3            115.67
# 4            126.38

# %%
def swap_columns(dataframe, column1, column2):
    dataframe[column1], dataframe[column2] = dataframe[column2].copy(), dataframe[column1].copy()
    dataframe.rename(columns={column1: column2, column2: column1}, inplace=True)
    return dataframe

df = swap_columns(df, 'Направление расходов', 'Наименование вида расходов')

df.head()
# Out:
#   Направление расходов Наименование вида расходов Вид объекта Дата проведения  \
# 0        Мордовцева, 6                         ЭЭ      Здание      13.01.2022
# 1       Пушкинская, 8б                         ЭЭ      Здание      19.01.2021
# 2       Пушкинская, 8б                         ЭЭ      Здание      20.02.2021
# 3       Пушкинская, 8б                         ЭЭ      Здание      22.03.2021
# 4       Пушкинская, 8б                         ЭЭ      Здание      21.04.2021
#
#    Конечный остаток
# 0          13920.02
# 1            226.79
# 2            161.12
# 3            115.67
# 4            126.38

# %%
# Сохранение файла в формате CSV с указанием кодировки UTF-8
df.to_csv('2021_обработанный_2.csv', index=False, encoding='Windows-1251')

# Сохранение в Excel
df.to_excel('2021_обработанный_2.xlsx', index=False)
