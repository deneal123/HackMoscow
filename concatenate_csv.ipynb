# %%
#Импортируем библиотеки
import numpy as np
import pandas as pd
import copy
import re
import openpyxl

# %%
# Читаем таблицу 2019.
df_2019 = pd.read_csv("C:/Users/NightMare/Desktop/YandexHack/DATA_Pretrained/2019_обработанный.csv", encoding='Windows-1251')
# Читаем таблицу 2020_old.
df_2020_old = pd.read_csv("C:/Users/NightMare/Desktop/YandexHack/DATA_Pretrained/2020_old_обработанный.csv", encoding='Windows-1251')
# Читаем таблицу 2020_new.
df_2020_new = pd.read_csv("C:/Users/NightMare/Desktop/YandexHack/DATA_Pretrained/2020_new_обработанный.csv", encoding='Windows-1251')
# Читаем таблицу 2021.
df_2021 = pd.read_csv("C:/Users/NightMare/Desktop/YandexHack/DATA_Pretrained/2021_обработанный.csv", encoding='Windows-1251')

# %%
# Список имен DataFrame, которые вы хотите объединить
df_names = [df_2019, df_2020_old, df_2020_new, df_2021]

# %%
df_2019.head()
# Out:
#                                     Подразделение БР Код вида расходов  \
# 0  Дальневосточное главное управление Центральног...   134.1100.000000
# 1  Дальневосточное главное управление Центральног...   134.1100.000000
# 2  Дальневосточное главное управление Центральног...   134.1100.000000
# 3  Дальневосточное главное управление Центральног...   134.1100.000000
# 4  Дальневосточное главное управление Центральног...   134.1100.000000
#
#        Наименование вида расходов    Направление расходов Вид объекта  \
# 0  Расходы на коммунальные услуги  ул.Верхнепортовая, 44       Здание
# 1  Расходы на коммунальные услуги  ул.Верхнепортовая, 44       Здание
# 2  Расходы на коммунальные услуги  ул.Верхнепортовая, 44       Здание
# 3  Расходы на коммунальные услуги  ул.Верхнепортовая, 44       Здание
# 4  Расходы на коммунальные услуги  ул.Верхнепортовая, 44       Здание
#
#    Дата проведения (день)  Дата проведения (месяц)  Дата проведения (год)  \
# ...

# %%
df_2020_old.head()
# Out:
#                                     Подразделение БР Код вида расходов  \
# 0  Дальневосточное главное управление Центральног...   134.1100.010000
# 1  Дальневосточное главное управление Центральног...   134.1100.010000
# 2  Дальневосточное главное управление Центральног...   134.1100.010000
# 3  Дальневосточное главное управление Центральног...   134.1100.010000
# 4  Дальневосточное главное управление Центральног...   134.1100.010000
#
#                      Наименование вида расходов  \
# 0  Расходы по оплате потребления электроэнергии
# 1  Расходы по оплате потребления электроэнергии
# 2  Расходы по оплате потребления электроэнергии
# 3  Расходы по оплате потребления электроэнергии
# 4  Расходы по оплате потребления электроэнергии
#
#                  Направление расходов Вид объекта  Дата проведения (день)  \
# 0     г. Владивосток ул. Калинина,261      Здание                      15
# 1  Вл-Александровское, ул. Седова, 23      Здание                      21
# ...

# %%
df_2020_new.head()
# Out:
#                                     Подразделение БР Код вида расходов  \
# 0  Дальневосточное главное управление Центральног...   134.1100.010000
# 1  Дальневосточное главное управление Центральног...   134.1100.010000
# 2  Дальневосточное главное управление Центральног...   134.1100.010000
# 3  Дальневосточное главное управление Центральног...   134.1100.010000
# 4  Дальневосточное главное управление Центральног...   134.1100.010000
#
#                      Наименование вида расходов  \
# 0  Расходы по оплате потребления электроэнергии
# 1  Расходы по оплате потребления электроэнергии
# 2  Расходы по оплате потребления электроэнергии
# 3  Расходы по оплате потребления электроэнергии
# 4  Расходы по оплате потребления электроэнергии
#
#                  Направление расходов Вид объекта  Дата проведения (день)  \
# 0     г. Владивосток ул. Калинина,261      Здание                      31
# 1  Вл-Александровское, ул. Седова, 23      Здание                      31
# ...

# %%
df_2021.head()
# Out:
#                                     Подразделение БР Код вида расходов  \
# 0  Дальневосточное главное управление Центральног...   134.1000.010000
# 1  Дальневосточное главное управление Центральног...   134.1000.010000
# 2  Дальневосточное главное управление Центральног...   134.1000.010000
# 3  Дальневосточное главное управление Центральног...   134.1000.010000
# 4  Дальневосточное главное управление Центральног...   134.1000.010000
#
#           Наименование вида расходов Направление расходов Вид объекта  \
# 0  Оплата потребления электроэнергии     ул.Мордовцева, 6      Здание
# 1  Оплата потребления электроэнергии    ул.Пушкинская, 8б      Здание
# 2  Оплата потребления электроэнергии    ул.Пушкинская, 8б      Здание
# 3  Оплата потребления электроэнергии    ул.Пушкинская, 8б      Здание
# 4  Оплата потребления электроэнергии    ул.Пушкинская, 8б      Здание
#
#    Дата проведения (день)  Дата проведения (месяц)  Дата проведения (год)  \
# ...

# %%
# Создайте пустой DataFrame, в который будут добавлены данные
combined_data = pd.DataFrame()

# %%
# Объедините файлы по вертикали
for df in df_names:
    # Добавьте данные к общему DataFrame
    combined_data = pd.concat([combined_data, df], ignore_index=True)

# %%
# Сохраните объединенные данные в новый CSV файл
combined_data.to_csv('combined_data.csv', index=False)

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8165 entries, 0 to 8164
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Подразделение БР            8165 non-null   object
#  1   Код вида расходов           8165 non-null   object
#  2   Наименование вида расходов  8165 non-null   object
#  3   Направление расходов        8165 non-null   object
#  4   Вид объекта                 8165 non-null   object
#  5   Дата проведения (день)      8165 non-null   int64
#  6   Дата проведения (месяц)     8165 non-null   int64
#  7   Дата проведения (год)       8165 non-null   int64
#  8   Конечный остаток            8165 non-null   float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 574.2+ KB

# %%
combined_data.head()
# Out:
#                                     Подразделение БР Код вида расходов  \
# 0  Дальневосточное главное управление Центральног...   134.1100.000000
# 1  Дальневосточное главное управление Центральног...   134.1100.000000
# 2  Дальневосточное главное управление Центральног...   134.1100.000000
# 3  Дальневосточное главное управление Центральног...   134.1100.000000
# 4  Дальневосточное главное управление Центральног...   134.1100.000000
#
#        Наименование вида расходов    Направление расходов Вид объекта  \
# 0  Расходы на коммунальные услуги  ул.Верхнепортовая, 44       Здание
# 1  Расходы на коммунальные услуги  ул.Верхнепортовая, 44       Здание
# 2  Расходы на коммунальные услуги  ул.Верхнепортовая, 44       Здание
# 3  Расходы на коммунальные услуги  ул.Верхнепортовая, 44       Здание
# 4  Расходы на коммунальные услуги  ул.Верхнепортовая, 44       Здание
#
#    Дата проведения (день)  Дата проведения (месяц)  Дата проведения (год)  \
# ...
